# %%
import numpy as np 
import pandas as pd 
df=pd.read_csv('data/boston-public-schools/Public_Schools.csv')

# %%
df.head()
# Out:
#            X          Y  OBJECTID_1  OBJECTID  BLDG_ID              BLDG_NAME  \
# 0 -71.004121  42.388799           1         1        1             Guild Bldg
# 1 -71.030480  42.378545           2         2        3        Kennedy, P Bldg
# 2 -71.033891  42.375279           3         3        4              Otis Bldg
# 3 -71.038011  42.378089           4         4        6          Odonnell Bldg
# 4 -71.034921  42.380957           5         5        7  East Boston High Bldg
#
#                ADDRESS         CITY  ZIPCODE  CSP_SCH_ID  ...  \
# 0    195 Leyden Street  East Boston     2128        4061  ...
# 1  343 Saratoga Street  East Boston     2128        4541  ...
# 2    218 Marion Street  East Boston     2128        4322  ...
# 3    33 Trenton Street  East Boston     2128        4543  ...
# 4      86 White Street  East Boston     2128        1070  ...
#
#                SCH_NAME       SCH_LABEL SCH_TYPE SHARED COMPLEX Label  TLT  \
# 0      Guild Elementary           Guild       ES                   52    3
# 1  Kennedy Patrick Elem      PJ Kennedy       ES                   72    3
# 2       Otis Elementary            Otis       ES                  106    3
# 3  O'Donnell Elementary       O'Donnell       ES                  103    3
# 4      East Boston High  East Boston HS       HS                   36    2
#
#       PL        POINT_X       POINT_Y
# 0  Grace  790128.152748  2.967094e+06
# 1  Grace  783027.745829  2.963318e+06
# 2  Grace  782112.823908  2.962122e+06
# 3  Grace  780994.000003  2.963140e+06
# 4   Joel  781823.000004  2.964190e+06
#
# [5 rows x 21 columns]

# %% [markdown]
# ## [Folium](http://python-visualization.github.io/folium/docs-v0.5.0/)
#
#
# **Python data, leaflet.js maps** <br>
# folium builds on the data wrangling strengths of the Python ecosystem and the mapping strengths of the leaflet.js library. Manipulate your data in Python, then visualize it in on a Leaflet map via folium.<br>
#
# **Concepts**<br>
# folium makes it easy to visualize data that’s been manipulated in Python on an interactive leaflet map. It enables both the binding of data to a map for choropleth visualizations as well as passing rich vector/raster/HTML visualizations as markers on the map.
#
# The library has a number of built-in tilesets from OpenStreetMap, Mapbox, and Stamen, and supports custom tilesets with Mapbox or Cloudmade API keys. folium supports both Image, Video, GeoJSON and TopoJSON overlays.
#
# **Installing: **<br>
#  pip install folium <br>
#  conda install folium -c conda-forge
#
# This is called the Folim Library, it's a library to show some data on maps simply. I think I'm familiar with some of the examples I'll share with you. I know you need something like this, especially for my friends from the GIS. We'll explain the school names on the map and color the special icon. According to the type of school, and also we will divide them geographically and we will learn some simple functions as an introduction in that library

# %%
# !pip install folium==0.14.0
# Out:
# Requirement already satisfied: folium==0.14.0 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (0.14.0)
# Requirement already satisfied: jinja2>=2.9 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from folium==0.14.0) (2.10)
# Requirement already satisfied: requests in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from folium==0.14.0) (2.21.0)
# Requirement already satisfied: branca>=0.6.0 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from folium==0.14.0) (0.6.0)
# Requirement already satisfied: numpy in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from folium==0.14.0) (1.16.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from jinja2>=2.9->folium==0.14.0) (1.1.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from requests->folium==0.14.0) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from requests->folium==0.14.0) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from requests->folium==0.14.0) (2020.12.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from requests->folium==0.14.0) (3.0.4)

# %%
import folium

# %% [markdown]
# For Making a simple map w'll use folium.Map function and set location and zoom_start for appearing the map it's so simple and easy we will try it
# We will determine latitude and longitude for Boston, this is simply Map view without any Type , there is alot of type of maps you can look at Docs for more information about it

# %%
lat=42.292193
lang=-71.097283
folium.Map(location=[lat,lang],zoom_start=12)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_afd9ba0222b912f14fbe075af6b58575 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_afd9ba0222b912f14fbe075af6b58575&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_afd9ba0222b912f14fbe075af6b58575 = L.map(
#                 &quot;map_afd9ba0222b912f14fbe075af6b58575&quot;,
#                 {
#                     center: [42.292193, -71.097283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93e0d3ba1edc0b983b4ba913ba03c47d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_afd9ba0222b912f14fbe075af6b58575);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# * **Mapbox Control Room:**

# %%
# folium.Map(location=[lat,lang],zoom_start=8,tiles='Mapbox Control Room')

# %% [markdown]
# * **Stamen Watercolor:**

# %%
folium.Map(location=[lat,lang],zoom_start=12,tiles='Stamen Watercolor')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f92fae0ab83b7f83a5bf9cfa35d90cfc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f92fae0ab83b7f83a5bf9cfa35d90cfc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f92fae0ab83b7f83a5bf9cfa35d90cfc = L.map(
#                 &quot;map_f92fae0ab83b7f83a5bf9cfa35d90cfc&quot;,
#                 {
#                     center: [42.292193, -71.097283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02683ac28c9890d5400bf0b3f0c06356 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f92fae0ab83b7f83a5bf9cfa35d90cfc);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# * **Mapbox Control Room:**

# %%
folium.Map(location=[lat,lang],zoom_start=12,tiles='Stamen Terrain')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52b38a4ce86b53e5547b734b49aa52ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52b38a4ce86b53e5547b734b49aa52ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52b38a4ce86b53e5547b734b49aa52ea = L.map(
#                 &quot;map_52b38a4ce86b53e5547b734b49aa52ea&quot;,
#                 {
#                     center: [42.292193, -71.097283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fabd17bfb26436f8590b416a71756a10 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_52b38a4ce86b53e5547b734b49aa52ea);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# * **Stamen Toner Map:**

# %%
folium.Map(location=[lat,lang],zoom_start=12,tiles='Stamen Toner')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ade6e01b24a825ebd1029b42a324709 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ade6e01b24a825ebd1029b42a324709&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ade6e01b24a825ebd1029b42a324709 = L.map(
#                 &quot;map_8ade6e01b24a825ebd1029b42a324709&quot;,
#                 {
#                     center: [42.292193, -71.097283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6de39b9963485c3d5b3291ac88092b17 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8ade6e01b24a825ebd1029b42a324709);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
colors={'ES':'red' , 
'K-8':'blue'  ,        
'HS':'purple'   ,        
'Special':'green',   
'6/7-12':'brick',    
'K-12':'red',       
'MS':'gray',   
'ELC':'orange',   
       }

# %% [markdown]
# We will check each row and we will add its color based on its type, then we will show it on the map and when pressed it will show the name of the school, it is simple and very easy You can read the code is very simple

# %%
boston_circle=folium.Map(location=[lat,lang],zoom_start=12)
for lat,lng,num in zip(df.Y,df.X,range(1,df.shape[0])): 
         popup = folium.Popup(df['SCH_NAME'][num], parse_html=True)
         folium.CircleMarker(
                    [lat,lng],
                    radius=6,
                    color=colors[df.iloc[num,-8]],
                    fill=True,
                    fill_color=colors[df.iloc[num,-8]],
                    fill_opacity=0.7,
                    popup=popup
            ).add_to(boston_circle)
boston_circle
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d77cb20b83e77f05bae2dcb41120119d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d77cb20b83e77f05bae2dcb41120119d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d77cb20b83e77f05bae2dcb41120119d = L.map(
#                 &quot;map_d77cb20b83e77f05bae2dcb41120119d&quot;,
#                 {
#                     center: [42.292193, -71.097283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9b2ae202158d00073a7fac70cd80998 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d77cb20b83e77f05bae2dcb41120119d);
#
#
#             var circle_marker_76161d76938d8a761a852e7ae8a6ade8 = L.circleMarker(
#                 [42.38879868107347, -71.00412057520259],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d77cb20b83e77f05bae2dcb41120119d);
#
#
#         var popup_7c869d041227e1cce953ceee3cf1c188 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d1c5ed10caca576c7f17bf91f956ecb = $(`&lt;div id=&quot;html_7d1c5ed10caca576c7f17bf91f956ecb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kennedy Patrick Elem&lt;/div&gt;`)[0];
#                 popup_7c869d041227e1cce953ceee3cf1c188.setContent(html_7d1c5ed10caca576c7f17bf91f956ecb);
#
#
#
#         circle_marker_76161d76938d8a761a852e7ae8a6ade8.bindPopup(popup_7c869d041227e1cce953ceee3cf1c188)
#         ;
#
#
#
#
#             var circle_marker_856ca169c2506de53f36f9ced10f661f = L.circleMarker(
#                 [42.378545298399885, -71.03048029238414],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d77cb20b83e77f05bae2dcb41120119d);
#
#
#         var popup_b7a92ee319e5482ad794c98dd3992a74 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_71acfd7105f2fe7a68ebdf1909d8383e = $(`&lt;div id=&quot;html_71acfd7105f2fe7a68ebdf1909d8383e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Otis Elementary&lt;/div&gt;`)[0];
#                 popup_b7a92ee319e5482ad794c98dd3992a74.setContent(html_71acfd7105f2fe7a68ebdf1909d8383e);
#
#
#
#         circle_marker_856ca169c2506de53f36f9ced10f661f.bindPopup(popup_b7a92ee319e5482ad794c98dd3992a74)
#         ;
#
#
#
#
#             var circle_marker_162c3a130c7acd8b81bcae7be5f01ed8 = L.circleMarker(
#                 [42.37527867715065, -71.03389058391973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d77cb20b83e77f05bae2dcb41120119d);
#
#
#         var popup_46dce71675cf4a65c9c1be1b356f15c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_581aec1497cf6e6a379b7ac4d5d42fcc = $(`&lt;div id=&quot;html_581aec1497cf6e6a379b7ac4d5d42fcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;O&amp;#39;Donnell Elementary&lt;/div&gt;`)[0];
#                 popup_46dce71675cf4a65c9c1be1b356f15c7.setContent(html_581aec1497cf6e6a379b7ac4d5d42fcc);
#
#
#
#         circle_marker_162c3a130c7acd8b81bcae7be5f01ed8.bindPopup(popup_46dce71675cf4a65c9c1be1b356f15c7)
#         ;
#
#
#
#
#             var circle_marker_0a4b79b6fc9a348d11d1b08a0ca0b49e = L.circleMarker(
#                 [42.37808861721215, -71.03801071815423],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&q

# %% [markdown]
# We will do what we did before but here we will only add a colored Marker , not a circle

# %%
boston_Marker=folium.Map(location=[lat,lang],zoom_start=12)
for lat,lng,num in zip(df.Y,df.X,range(1,df.shape[0])): 
         popup = folium.Popup(df['SCH_NAME'][num], parse_html=True)
         folium.Marker(
                    [lat,lng],
                    popup=popup,
                    icon=folium.Icon(color=colors[df.iloc[num,-8]])
            ).add_to(boston_Marker)
boston_Marker
# Out:
# /home/notebookuser/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: color argument of Icon should be one of: {'beige', 'blue', 'black', 'lightred', 'darkblue', 'orange', 'pink', 'lightgray', 'lightblue', 'gray', 'lightgreen', 'white', 'purple', 'green', 'red', 'darkgreen', 'darkred', 'cadetblue', 'darkpurple'}.
#   import sys
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_723e04065bf8f7b9081838d423867c07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_723e04065bf8f7b9081838d423867c07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_723e04065bf8f7b9081838d423867c07 = L.map(
#                 &quot;map_723e04065bf8f7b9081838d423867c07&quot;,
#                 {
#                     center: [42.350440724681775, -71.097283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc975e25f162aaf639a06f8638a2ba09 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_723e04065bf8f7b9081838d423867c07);
#
#
#             var marker_e3b24be2a16979bb4a1121ec05d27df3 = L.marker(
#                 [42.38879868107347, -71.00412057520259],
#                 {}
#             ).addTo(map_723e04065bf8f7b9081838d423867c07);
#
#
#             var icon_a0dc818b81fa1603339076b73a100748 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e3b24be2a16979bb4a1121ec05d27df3.setIcon(icon_a0dc818b81fa1603339076b73a100748);
#
#
#         var popup_bf7322784fd5555c143c68a597737ab3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_172d43a1f009dd9c1d9b3c2aa7b5d800 = $(`&lt;div id=&quot;html_172d43a1f009dd9c1d9b3c2aa7b5d800&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kennedy Patrick Elem&lt;/div&gt;`)[0];
#                 popup_bf7322784fd5555c143c68a597737ab3.setContent(html_172d43a1f009dd9c1d9b3c2aa7b5d800);
#
#
#
#         marker_e3b24be2a16979bb4a1121ec05d27df3.bindPopup(popup_bf7322784fd5555c143c68a597737ab3)
#         ;
#
#
#
#
#             var marker_015d03f952d4003745d7c966097b1f33 = L.marker(
#                 [42.378545298399885, -71.03048029238414],
#                 {}
#             ).addTo(map_723e04065bf8f7b9081838d423867c07);
#
#
#             var icon_4c033cfb7b804232081505e1fd7b126e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_015d03f952d4003745d7c966097b1f33.setIcon(icon_4c033cfb7b804232081505e1fd7b126e);
#
#
#         var popup_f8a49703591e7412436ed48f64526a85 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a66cf8f7be8766bf6a900bd371cd079 = $(`&lt;div id=&quot;html_9a66cf8f7be8766bf6a900bd371cd079&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Otis Elementary&lt;/div&gt;`)[0];
#                 popup_f8a49703591e7412436ed48f64526a85.setContent(html_9a66cf8f7be8766bf6a900bd371cd079);
#
#
#
#         marker_015d03f952d4003745d7c966097b1f33.bindPopup(popup_f8a49703591e7412436ed48f64526a85)
#         ;
#
#
#
#
#             var marker_63f0abb0999494f1fdda402ce8e2d627 = L.marker(
#                 [42.37527867715065, -71.03389058391973],
#                 {}
#             ).addTo(map_723e04065bf8f7b9081838d423867c07);
#
#
#             var icon_d7be14fbf65a9c705bb4b779bd4c284d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_63f0abb0999494f1fdda402ce8e2d627.setIcon(icon_d7be14fbf65a9c705bb4b779bd4c284d);
#
#
#         var popup_314d513acb9f1f9a17ec90af909e1a97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d13703c43e735420e57840c6f43094a = $(`&lt;div id=&quot;html_8d13703c43e735420e57840c6f43094a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;O&amp;#39;Donnell Elementary&lt;/div&gt;`)[0];
#                 popup_314d513acb9f1f9a17ec90af909e1a97.setContent(html_8d13703c43e735420e57840c6f43094a);
#
#
#
#         marker_63f0abb0999494f1fdda402ce8e2d627.bindPopup(popup_314d513acb9f1f9a17ec90af909e1a97)
#         ;
#
#
#
#
#             var marker_ce8d2ab1295fcbb3c7cf65fee330c28e = L.marker(
#                 [42.37808861721215, -71.03801071815423],
#                 {}
#             ).addTo(map_723e04065bf8f7b9081838d423867c07);
#
#
#             var icon_6377b5f0f19cc75cddb1e306424ac4e1 = L.AwesomeMarkers.

# %% [markdown]
# We will do what we did again but here will happen something new, we will divide the schools according to its geographical location do not worry Library do everything, this will make it easier to read the map reader a lot

# %%
boston_cluster=folium.Map(location=[lat,lang],zoom_start=12)
from folium import plugins
cluster=plugins.MarkerCluster().add_to(boston_cluster)

boston_Marker=folium.Map(location=[lat,lang],zoom_start=12)
for lat,lng,num in zip(df.Y,df.X,range(1,df.shape[0])): 
         popup = folium.Popup(df['SCH_NAME'][num], parse_html=True)
         folium.Marker(
                    [lat,lng],
                    popup=popup,
                    icon=folium.Icon(color=colors[df.iloc[num,-8]])
            ).add_to(cluster)
boston_cluster
# Out:
# /home/notebookuser/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: color argument of Icon should be one of: {'beige', 'blue', 'black', 'lightred', 'darkblue', 'orange', 'pink', 'lightgray', 'lightblue', 'gray', 'lightgreen', 'white', 'purple', 'green', 'red', 'darkgreen', 'darkred', 'cadetblue', 'darkpurple'}.
#   # This is added back by InteractiveShellApp.init_path()
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_faa8ab23b805696a460856fefd3f4d3e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_faa8ab23b805696a460856fefd3f4d3e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_faa8ab23b805696a460856fefd3f4d3e = L.map(
#                 &quot;map_faa8ab23b805696a460856fefd3f4d3e&quot;,
#                 {
#                     center: [42.350440724681775, -71.097283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1487df56acea90312deebd3ced6d85da = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_faa8ab23b805696a460856fefd3f4d3e);
#
#
#             var marker_cluster_435b041453a11d2ba07bea16f5507ade = L.markerClusterGroup(
#                 {}
#             );
#             map_faa8ab23b805696a460856fefd3f4d3e.addLayer(marker_cluster_435b041453a11d2ba07bea16f5507ade);
#
#
#             var marker_182ed9b81cd70caedd374564338e7441 = L.marker(
#                 [42.38879868107347, -71.00412057520259],
#                 {}
#             ).addTo(marker_cluster_435b041453a11d2ba07bea16f5507ade);
#
#
#             var icon_dd019a9df4d7597f46df9b49e58c2cb6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_182ed9b81cd70caedd374564338e7441.setIcon(icon_dd019a9df4d7597f46df9b49e58c2cb6);
#
#
#         var popup_12877004e920e99178184bb0ead4945c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d1d4d68229147d48de96b6eb1409b474 = $(`&lt;div id=&quot;html_d1d4d68229147d48de96b6eb1409b474&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kennedy Patrick Elem&lt;/div&gt;`)[0];
#                 popup_12877004e920e99178184bb0ead4945c.setContent(html_d1d4d68229147d48de96b6eb1409b474);
#
#
#
#         marker_182ed9b81cd70caedd374564338e7441.bindPopup(popup_12877004e920e99178184bb0ead4945c)
#         ;
#
#
#
#
#             var marker_7bbf13c21483df9deada90a6d28f61c5 = L.marker(
#                 [42.378545298399885, -71.03048029238414],
#                 {}
#             ).addTo(marker_cluster_435b041453a11d2ba07bea16f5507ade);
#
#
#             var icon_a0df5363dd7aae5e0a60cee7c2510078 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7bbf13c21483df9deada90a6d28f61c5.setIcon(icon_a0df5363dd7aae5e0a60cee7c2510078);
#
#
#         var popup_d7a35ffcdd74c27dd34e7d973534865f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6fa1fd2591f92829ae7d24d01e8fd2c2 = $(`&lt;div id=&quot;html_6fa1fd2591f92829ae7d24d01e8fd2c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Otis Elementary&lt;/div&gt;`)[0];
#                 popup_d7a35ffcdd74c27dd34e7d973534865f.setContent(html_6fa1fd2591f92829ae7d24d01e8fd2c2);
#
#
#
#         marker_7bbf13c21483df9deada90a6d28f61c5.bindPopup(popup_d7a35ffcdd74c27dd34e7d973534865f)
#         ;
#
#
#
#
#             var marker_851f7dfec1345b38ff08cc3df69947c6 = L.marker(
#                 [42.37527867715065, -71.03389058391973],
#                 {}
#             ).addTo(marker_cluster_435b041453a11d2ba07bea16f5507ade);
#
#
#             var icon_a97e2f6c1b533c0bb5b5188842a5f3cb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_851f7dfec1345b38ff08cc3df69947c6.setIcon(icon_a97e2f6c1b533c0bb5b5188842a5f3cb);
#
#
#         var popup_8f0497180b36e1163500210cd849489a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c81f4dd0a903a4f4901d2be

# %% [markdown]
# oh remember, you can always save that map with this code :

# %%
boston_cluster.save('container-Folium-cluster.html')

# %% [markdown]
# Know that these may be the fastest Kernel you have read in your life
# But you are just beginning, you can take care of this library You have the basics You can restore the examples in the explanation page, always take care of the application by yourself and do not be impressed by those attractive colors only, Well you will Promise what I have done yourself , and show the title of the school after the name when pressed in the map, There are many features and more in-depth explanations on YouTube, enjoy GIS <br> ** Loai abdalslam**

# %%
exit()
# Out:
# ERROR:root:Invalid alias: The name clear can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name more can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name less can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name man can't be aliased because it is another magic command.
