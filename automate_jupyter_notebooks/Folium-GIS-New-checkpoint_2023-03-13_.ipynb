# %%
import numpy as np 
import pandas as pd 
df=pd.read_csv('data/boston-public-schools/Public_Schools.csv')

# %%
df.head()
# Out:
#            X          Y  OBJECTID_1  OBJECTID  BLDG_ID              BLDG_NAME  \
# 0 -71.004121  42.388799           1         1        1             Guild Bldg
# 1 -71.030480  42.378545           2         2        3        Kennedy, P Bldg
# 2 -71.033891  42.375279           3         3        4              Otis Bldg
# 3 -71.038011  42.378089           4         4        6          Odonnell Bldg
# 4 -71.034921  42.380957           5         5        7  East Boston High Bldg
#
#                ADDRESS         CITY  ZIPCODE  CSP_SCH_ID  ...  \
# 0    195 Leyden Street  East Boston     2128        4061  ...
# 1  343 Saratoga Street  East Boston     2128        4541  ...
# 2    218 Marion Street  East Boston     2128        4322  ...
# 3    33 Trenton Street  East Boston     2128        4543  ...
# 4      86 White Street  East Boston     2128        1070  ...
#
#                SCH_NAME       SCH_LABEL SCH_TYPE SHARED COMPLEX Label  TLT  \
# 0      Guild Elementary           Guild       ES                   52    3
# 1  Kennedy Patrick Elem      PJ Kennedy       ES                   72    3
# 2       Otis Elementary            Otis       ES                  106    3
# 3  O'Donnell Elementary       O'Donnell       ES                  103    3
# 4      East Boston High  East Boston HS       HS                   36    2
#
#       PL        POINT_X       POINT_Y
# 0  Grace  790128.152748  2.967094e+06
# 1  Grace  783027.745829  2.963318e+06
# 2  Grace  782112.823908  2.962122e+06
# 3  Grace  780994.000003  2.963140e+06
# 4   Joel  781823.000004  2.964190e+06
#
# [5 rows x 21 columns]

# %% [markdown]
# ## [Folium](http://python-visualization.github.io/folium/docs-v0.5.0/)
#
#
# **Python data, leaflet.js maps** <br>
# folium builds on the data wrangling strengths of the Python ecosystem and the mapping strengths of the leaflet.js library. Manipulate your data in Python, then visualize it in on a Leaflet map via folium.<br>
#
# **Concepts**<br>
# folium makes it easy to visualize data that’s been manipulated in Python on an interactive leaflet map. It enables both the binding of data to a map for choropleth visualizations as well as passing rich vector/raster/HTML visualizations as markers on the map.
#
# The library has a number of built-in tilesets from OpenStreetMap, Mapbox, and Stamen, and supports custom tilesets with Mapbox or Cloudmade API keys. folium supports both Image, Video, GeoJSON and TopoJSON overlays.
#
# **Installing: **<br>
#  pip install folium <br>
#  conda install folium -c conda-forge
#
# This is called the Folim Library, it's a library to show some data on maps simply. I think I'm familiar with some of the examples I'll share with you. I know you need something like this, especially for my friends from the GIS. We'll explain the school names on the map and color the special icon. According to the type of school, and also we will divide them geographically and we will learn some simple functions as an introduction in that library

# %%
# !pip install folium==0.14.0
# Out:
# Requirement already satisfied: folium==0.14.0 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (0.14.0)
# Requirement already satisfied: jinja2>=2.9 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from folium==0.14.0) (2.10)
# Requirement already satisfied: branca>=0.6.0 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from folium==0.14.0) (0.6.0)
# Requirement already satisfied: requests in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from folium==0.14.0) (2.21.0)
# Requirement already satisfied: numpy in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from folium==0.14.0) (1.16.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from jinja2>=2.9->folium==0.14.0) (1.1.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from requests->folium==0.14.0) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from requests->folium==0.14.0) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from requests->folium==0.14.0) (2020.12.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/notebookuser/anaconda3/lib/python3.7/site-packages (from requests->folium==0.14.0) (3.0.4)

# %%
import folium

# %% [markdown]
# For Making a simple map w'll use folium.Map function and set location and zoom_start for appearing the map it's so simple and easy we will try it
# We will determine latitude and longitude for Boston, this is simply Map view without any Type , there is alot of type of maps you can look at Docs for more information about it

# %%
lat=42.292193
lang=-71.097283
folium.Map(location=[lat,lang],zoom_start=12)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2346653bb47eada92b655b0c7def4549 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2346653bb47eada92b655b0c7def4549&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2346653bb47eada92b655b0c7def4549 = L.map(
#                 &quot;map_2346653bb47eada92b655b0c7def4549&quot;,
#                 {
#                     center: [42.292193, -71.097283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29271c32d7b7b1e1229d6c6980f43c35 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2346653bb47eada92b655b0c7def4549);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# * **Mapbox Control Room:**

# %%
# folium.Map(location=[lat,lang],zoom_start=8,tiles='Mapbox Control Room')

# %% [markdown]
# * **Stamen Watercolor:**

# %%
folium.Map(location=[lat,lang],zoom_start=12,tiles='Stamen Watercolor')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2dc15a044a8dbc675f3085c967992280 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2dc15a044a8dbc675f3085c967992280&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2dc15a044a8dbc675f3085c967992280 = L.map(
#                 &quot;map_2dc15a044a8dbc675f3085c967992280&quot;,
#                 {
#                     center: [42.292193, -71.097283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9921e540e46f0721433c06b6757e94c8 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2dc15a044a8dbc675f3085c967992280);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# * **Mapbox Control Room:**

# %%
folium.Map(location=[lat,lang],zoom_start=12,tiles='Stamen Terrain')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc71213d72e2cca4b67a608625468a5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc71213d72e2cca4b67a608625468a5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc71213d72e2cca4b67a608625468a5f = L.map(
#                 &quot;map_fc71213d72e2cca4b67a608625468a5f&quot;,
#                 {
#                     center: [42.292193, -71.097283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3039ba3b0c83ec3a614d024fb872fd26 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fc71213d72e2cca4b67a608625468a5f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# * **Stamen Toner Map:**

# %%
folium.Map(location=[lat,lang],zoom_start=12,tiles='Stamen Toner')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_845c9a9c19d68d4104b120916e7ea871 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_845c9a9c19d68d4104b120916e7ea871&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_845c9a9c19d68d4104b120916e7ea871 = L.map(
#                 &quot;map_845c9a9c19d68d4104b120916e7ea871&quot;,
#                 {
#                     center: [42.292193, -71.097283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5fda4a441b74218c0ecc8ae57b42066 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_845c9a9c19d68d4104b120916e7ea871);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
colors={'ES':'red' , 
'K-8':'blue'  ,        
'HS':'purple'   ,        
'Special':'green',   
'6/7-12':'brick',    
'K-12':'red',       
'MS':'gray',   
'ELC':'orange',   
       }

# %% [markdown]
# We will check each row and we will add its color based on its type, then we will show it on the map and when pressed it will show the name of the school, it is simple and very easy You can read the code is very simple

# %%
boston_circle=folium.Map(location=[lat,lang],zoom_start=12)
for lat,lng,num in zip(df.Y,df.X,range(1,df.shape[0])): 
         popup = folium.Popup(df['SCH_NAME'][num], parse_html=True)
         folium.CircleMarker(
                    [lat,lng],
                    radius=6,
                    color=colors[df.iloc[num,-8]],
                    fill=True,
                    fill_color=colors[df.iloc[num,-8]],
                    fill_opacity=0.7,
                    popup=popup
            ).add_to(boston_circle)
boston_circle
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9beb04c09ae071af73d58813972dc1fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9beb04c09ae071af73d58813972dc1fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9beb04c09ae071af73d58813972dc1fd = L.map(
#                 &quot;map_9beb04c09ae071af73d58813972dc1fd&quot;,
#                 {
#                     center: [42.292193, -71.097283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_997c15d4a32a193f020241d081322c82 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9beb04c09ae071af73d58813972dc1fd);
#
#
#             var circle_marker_f1cdda978ffa85bd609f27705744c57b = L.circleMarker(
#                 [42.38879868107347, -71.00412057520259],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9beb04c09ae071af73d58813972dc1fd);
#
#
#         var popup_66706c8b92c06b322fcbe479d4ab5040 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68700550cc72341d46d3dea2dfa22167 = $(`&lt;div id=&quot;html_68700550cc72341d46d3dea2dfa22167&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kennedy Patrick Elem&lt;/div&gt;`)[0];
#                 popup_66706c8b92c06b322fcbe479d4ab5040.setContent(html_68700550cc72341d46d3dea2dfa22167);
#
#
#
#         circle_marker_f1cdda978ffa85bd609f27705744c57b.bindPopup(popup_66706c8b92c06b322fcbe479d4ab5040)
#         ;
#
#
#
#
#             var circle_marker_9ac842a05ce9b22e88028b8da9a6d2b8 = L.circleMarker(
#                 [42.378545298399885, -71.03048029238414],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9beb04c09ae071af73d58813972dc1fd);
#
#
#         var popup_a8ee965c450cc99fb6e9b7484595c4ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_84feb5e2937bf5cfa1cb3ce5b2af06b6 = $(`&lt;div id=&quot;html_84feb5e2937bf5cfa1cb3ce5b2af06b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Otis Elementary&lt;/div&gt;`)[0];
#                 popup_a8ee965c450cc99fb6e9b7484595c4ff.setContent(html_84feb5e2937bf5cfa1cb3ce5b2af06b6);
#
#
#
#         circle_marker_9ac842a05ce9b22e88028b8da9a6d2b8.bindPopup(popup_a8ee965c450cc99fb6e9b7484595c4ff)
#         ;
#
#
#
#
#             var circle_marker_f909268e12fa1edd2bc4d8012955edd9 = L.circleMarker(
#                 [42.37527867715065, -71.03389058391973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9beb04c09ae071af73d58813972dc1fd);
#
#
#         var popup_a97e3c6d8a4e41f9f869d179f3510c9d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cac32a691de779221b6c34881b8d4ee1 = $(`&lt;div id=&quot;html_cac32a691de779221b6c34881b8d4ee1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;O&amp;#39;Donnell Elementary&lt;/div&gt;`)[0];
#                 popup_a97e3c6d8a4e41f9f869d179f3510c9d.setContent(html_cac32a691de779221b6c34881b8d4ee1);
#
#
#
#         circle_marker_f909268e12fa1edd2bc4d8012955edd9.bindPopup(popup_a97e3c6d8a4e41f9f869d179f3510c9d)
#         ;
#
#
#
#
#             var circle_marker_ae933637561faa336ad84e227415410b = L.circleMarker(
#                 [42.37808861721215, -71.03801071815423],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&q

# %% [markdown]
# We will do what we did before but here we will only add a colored Marker , not a circle

# %%
boston_Marker=folium.Map(location=[lat,lang],zoom_start=12)
for lat,lng,num in zip(df.Y,df.X,range(1,df.shape[0])): 
         popup = folium.Popup(df['SCH_NAME'][num], parse_html=True)
         folium.Marker(
                    [lat,lng],
                    popup=popup,
                    icon=folium.Icon(color=colors[df.iloc[num,-8]])
            ).add_to(boston_Marker)
boston_Marker
# Out:
# /home/notebookuser/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: color argument of Icon should be one of: {'black', 'darkblue', 'white', 'darkpurple', 'gray', 'pink', 'cadetblue', 'lightred', 'purple', 'red', 'blue', 'beige', 'lightblue', 'darkred', 'green', 'lightgreen', 'orange', 'darkgreen', 'lightgray'}.
#   import sys
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5281f5fd2d81aebcf7fd9024ef1609f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5281f5fd2d81aebcf7fd9024ef1609f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5281f5fd2d81aebcf7fd9024ef1609f1 = L.map(
#                 &quot;map_5281f5fd2d81aebcf7fd9024ef1609f1&quot;,
#                 {
#                     center: [42.350440724681775, -71.097283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a71d0f2956fbcc0505410941cc2ad905 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5281f5fd2d81aebcf7fd9024ef1609f1);
#
#
#             var marker_53d2332018af4ed7b39f55365ea1dd01 = L.marker(
#                 [42.38879868107347, -71.00412057520259],
#                 {}
#             ).addTo(map_5281f5fd2d81aebcf7fd9024ef1609f1);
#
#
#             var icon_2206c340325db0cd37eaea71ef626114 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_53d2332018af4ed7b39f55365ea1dd01.setIcon(icon_2206c340325db0cd37eaea71ef626114);
#
#
#         var popup_e76d22f9ca5908cfc1691bae5bc9dcc6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_729d7d8d6bda2e82aa87dbf6b5bda7ae = $(`&lt;div id=&quot;html_729d7d8d6bda2e82aa87dbf6b5bda7ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kennedy Patrick Elem&lt;/div&gt;`)[0];
#                 popup_e76d22f9ca5908cfc1691bae5bc9dcc6.setContent(html_729d7d8d6bda2e82aa87dbf6b5bda7ae);
#
#
#
#         marker_53d2332018af4ed7b39f55365ea1dd01.bindPopup(popup_e76d22f9ca5908cfc1691bae5bc9dcc6)
#         ;
#
#
#
#
#             var marker_9c38a8403d1d435a4a7ba801a1794e66 = L.marker(
#                 [42.378545298399885, -71.03048029238414],
#                 {}
#             ).addTo(map_5281f5fd2d81aebcf7fd9024ef1609f1);
#
#
#             var icon_7be42c118cb4387a5d2494b6bf6d405e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9c38a8403d1d435a4a7ba801a1794e66.setIcon(icon_7be42c118cb4387a5d2494b6bf6d405e);
#
#
#         var popup_6845a257ccc1dcd8bb8fe746e3d5a526 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ffbd9b25442a25ceffec1c7edbdb57d9 = $(`&lt;div id=&quot;html_ffbd9b25442a25ceffec1c7edbdb57d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Otis Elementary&lt;/div&gt;`)[0];
#                 popup_6845a257ccc1dcd8bb8fe746e3d5a526.setContent(html_ffbd9b25442a25ceffec1c7edbdb57d9);
#
#
#
#         marker_9c38a8403d1d435a4a7ba801a1794e66.bindPopup(popup_6845a257ccc1dcd8bb8fe746e3d5a526)
#         ;
#
#
#
#
#             var marker_e77efb5071574715ae32073be13da59e = L.marker(
#                 [42.37527867715065, -71.03389058391973],
#                 {}
#             ).addTo(map_5281f5fd2d81aebcf7fd9024ef1609f1);
#
#
#             var icon_d6b074b34ecc1b2ce51f282e62511a1c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e77efb5071574715ae32073be13da59e.setIcon(icon_d6b074b34ecc1b2ce51f282e62511a1c);
#
#
#         var popup_c306d1a3aafc1e7c66380af347886976 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_324694f1859c4cc4252fc7a064b81724 = $(`&lt;div id=&quot;html_324694f1859c4cc4252fc7a064b81724&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;O&amp;#39;Donnell Elementary&lt;/div&gt;`)[0];
#                 popup_c306d1a3aafc1e7c66380af347886976.setContent(html_324694f1859c4cc4252fc7a064b81724);
#
#
#
#         marker_e77efb5071574715ae32073be13da59e.bindPopup(popup_c306d1a3aafc1e7c66380af347886976)
#         ;
#
#
#
#
#             var marker_774cbe5b616539bc22a81262e7e52652 = L.marker(
#                 [42.37808861721215, -71.03801071815423],
#                 {}
#             ).addTo(map_5281f5fd2d81aebcf7fd9024ef1609f1);
#
#
#             var icon_9631b1f219cfec9f9adbb4e7d02739ba = L.AwesomeMarkers.

# %% [markdown]
# We will do what we did again but here will happen something new, we will divide the schools according to its geographical location do not worry Library do everything, this will make it easier to read the map reader a lot

# %%
boston_cluster=folium.Map(location=[lat,lang],zoom_start=12)
from folium import plugins
cluster=plugins.MarkerCluster().add_to(boston_cluster)

boston_Marker=folium.Map(location=[lat,lang],zoom_start=12)
for lat,lng,num in zip(df.Y,df.X,range(1,df.shape[0])): 
         popup = folium.Popup(df['SCH_NAME'][num], parse_html=True)
         folium.Marker(
                    [lat,lng],
                    popup=popup,
                    icon=folium.Icon(color=colors[df.iloc[num,-8]])
            ).add_to(cluster)
boston_cluster
# Out:
# /home/notebookuser/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: color argument of Icon should be one of: {'black', 'darkblue', 'white', 'darkpurple', 'gray', 'pink', 'cadetblue', 'lightred', 'purple', 'red', 'blue', 'beige', 'lightblue', 'darkred', 'green', 'lightgreen', 'orange', 'darkgreen', 'lightgray'}.
#   # This is added back by InteractiveShellApp.init_path()
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1f30cdb09286af60c98ffdc3dac4e4e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1f30cdb09286af60c98ffdc3dac4e4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1f30cdb09286af60c98ffdc3dac4e4e = L.map(
#                 &quot;map_b1f30cdb09286af60c98ffdc3dac4e4e&quot;,
#                 {
#                     center: [42.350440724681775, -71.097283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7ef9091a965691bcf1fe8f1de0bd7bb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b1f30cdb09286af60c98ffdc3dac4e4e);
#
#
#             var marker_cluster_c8afb502a673c36384cd0a57dff8a5b9 = L.markerClusterGroup(
#                 {}
#             );
#             map_b1f30cdb09286af60c98ffdc3dac4e4e.addLayer(marker_cluster_c8afb502a673c36384cd0a57dff8a5b9);
#
#
#             var marker_c2c536966c3b5add838c1ee61a395b76 = L.marker(
#                 [42.38879868107347, -71.00412057520259],
#                 {}
#             ).addTo(marker_cluster_c8afb502a673c36384cd0a57dff8a5b9);
#
#
#             var icon_49d8988420f6d68e056f370dab7d0084 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c2c536966c3b5add838c1ee61a395b76.setIcon(icon_49d8988420f6d68e056f370dab7d0084);
#
#
#         var popup_50151c4ebe4496450332cdc4b55025c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36b0eb24b168eed642267c549e612061 = $(`&lt;div id=&quot;html_36b0eb24b168eed642267c549e612061&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kennedy Patrick Elem&lt;/div&gt;`)[0];
#                 popup_50151c4ebe4496450332cdc4b55025c3.setContent(html_36b0eb24b168eed642267c549e612061);
#
#
#
#         marker_c2c536966c3b5add838c1ee61a395b76.bindPopup(popup_50151c4ebe4496450332cdc4b55025c3)
#         ;
#
#
#
#
#             var marker_c27a97ca604e8675ed12b6d34782df78 = L.marker(
#                 [42.378545298399885, -71.03048029238414],
#                 {}
#             ).addTo(marker_cluster_c8afb502a673c36384cd0a57dff8a5b9);
#
#
#             var icon_0d5caecf6ce5e6c32868dd4caa5b59be = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c27a97ca604e8675ed12b6d34782df78.setIcon(icon_0d5caecf6ce5e6c32868dd4caa5b59be);
#
#
#         var popup_560b50699da43d57b0a28b0f66a2a44d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27875acd483f17aa16aba052971e8736 = $(`&lt;div id=&quot;html_27875acd483f17aa16aba052971e8736&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Otis Elementary&lt;/div&gt;`)[0];
#                 popup_560b50699da43d57b0a28b0f66a2a44d.setContent(html_27875acd483f17aa16aba052971e8736);
#
#
#
#         marker_c27a97ca604e8675ed12b6d34782df78.bindPopup(popup_560b50699da43d57b0a28b0f66a2a44d)
#         ;
#
#
#
#
#             var marker_0e54fa43f5e6e4709d81fb68875b92ee = L.marker(
#                 [42.37527867715065, -71.03389058391973],
#                 {}
#             ).addTo(marker_cluster_c8afb502a673c36384cd0a57dff8a5b9);
#
#
#             var icon_a4a37d5291155ebbd427c1458788d690 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0e54fa43f5e6e4709d81fb68875b92ee.setIcon(icon_a4a37d5291155ebbd427c1458788d690);
#
#
#         var popup_f5c45c90c8dd902c486531a9a7bff488 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_19dcdd9944f2997aa2cbf9f8

# %% [markdown]
# oh remember, you can always save that map with this code :

# %%
boston_cluster.save('container-Folium-cluster.html')

# %% [markdown]
# Know that these may be the fastest Kernel you have read in your life
# But you are just beginning, you can take care of this library You have the basics You can restore the examples in the explanation page, always take care of the application by yourself and do not be impressed by those attractive colors only, Well you will Promise what I have done yourself , and show the title of the school after the name when pressed in the map, There are many features and more in-depth explanations on YouTube, enjoy GIS <br> ** Loai abdalslam**

# %%
exit()
